# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("D:\\medical-11\\data\\diet_recommendations_dataset.csv")

# %%
df.head()
# Out:
#   Patient_ID  Age  Gender  Weight_kg  Height_cm   BMI  Disease_Type  Severity  \
# 0      P0001   56    Male       58.4        160  22.8       Obesity  Moderate
# 1      P0002   69    Male      101.2        169  35.4      Diabetes      Mild
# 2      P0003   46  Female       63.5        173  21.2  Hypertension      Mild
# 3      P0004   32    Male       58.1        164  21.6           NaN      Mild
# 4      P0005   60    Male       79.5        197  20.5      Diabetes  Moderate
#
#   Physical_Activity_Level  Daily_Caloric_Intake  Cholesterol_mg/dL  \
# 0                Moderate                  3079              173.3
# 1                Moderate                  3032              199.2
# 2               Sedentary                  1737              181.0
# 3                Moderate                  2657              168.2
# 4               Sedentary                  3496              200.4
#
#    Blood_Pressure_mmHg  Glucose_mg/dL Dietary_Restrictions Allergies  \
# ...

# %% [markdown]
# droping the patient id as it is not important

# %%
df.drop(columns=['Patient_ID'],inplace=True)

# %%
df.head()
# Out:
#    Age  Gender  Weight_kg  Height_cm   BMI  Disease_Type  Severity  \
# 0   56    Male       58.4        160  22.8       Obesity  Moderate
# 1   69    Male      101.2        169  35.4      Diabetes      Mild
# 2   46  Female       63.5        173  21.2  Hypertension      Mild
# 3   32    Male       58.1        164  21.6           NaN      Mild
# 4   60    Male       79.5        197  20.5      Diabetes  Moderate
#
#   Physical_Activity_Level  Daily_Caloric_Intake  Cholesterol_mg/dL  \
# 0                Moderate                  3079              173.3
# 1                Moderate                  3032              199.2
# 2               Sedentary                  1737              181.0
# 3                Moderate                  2657              168.2
# 4               Sedentary                  3496              200.4
#
#    Blood_Pressure_mmHg  Glucose_mg/dL Dietary_Restrictions Allergies  \
# 0                  133          116.3                  NaN   Peanuts
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Age                               1000 non-null   int64
#  1   Gender                            1000 non-null   object
#  2   Weight_kg                         1000 non-null   float64
#  3   Height_cm                         1000 non-null   int64
#  4   BMI                               1000 non-null   float64
#  5   Disease_Type                      796 non-null    object
#  6   Severity                          1000 non-null   object
#  7   Physical_Activity_Level           1000 non-null   object
#  8   Daily_Caloric_Intake              1000 non-null   int64
#  9   Cholesterol_mg/dL                 1000 non-null   float64
#  10  Blood_Pressure_mmHg               1000 non-null   int64
# ...

# %%
df.shape
# Out:
# (1000, 19)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Age                                   0
# Gender                                0
# Weight_kg                             0
# Height_cm                             0
# BMI                                   0
# Disease_Type                        204
# Severity                              0
# Physical_Activity_Level               0
# Daily_Caloric_Intake                  0
# Cholesterol_mg/dL                     0
# Blood_Pressure_mmHg                   0
# Glucose_mg/dL                         0
# Dietary_Restrictions                334
# Allergies                           323
# Preferred_Cuisine                     0
# Weekly_Exercise_Hours                 0
# Adherence_to_Diet_Plan                0
# Dietary_Nutrient_Imbalance_Score      0
# Diet_Recommendation                   0
# dtype: int64

# %% [markdown]
# diesease type have 204 missing vale
# dietary restriction \
# \allergies have too

# %%
df['Age'].describe()
# Out:
# count    1000.000000
# mean       49.857000
# std        18.114267
# min        18.000000
# 25%        35.000000
# 50%        50.000000
# 75%        66.000000
# max        79.000000
# Name: Age, dtype: float64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      523
# Female    477
# Name: count, dtype: int64

# %%
df['Gender']=df['Gender'].map({'Male':1, 'Female':0}).astype(int)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# 1    523
# 0    477
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Age                               1000 non-null   int64
#  1   Gender                            1000 non-null   int64
#  2   Weight_kg                         1000 non-null   float64
#  3   Height_cm                         1000 non-null   int64
#  4   BMI                               1000 non-null   float64
#  5   Disease_Type                      796 non-null    object
#  6   Severity                          1000 non-null   object
#  7   Physical_Activity_Level           1000 non-null   object
#  8   Daily_Caloric_Intake              1000 non-null   int64
#  9   Cholesterol_mg/dL                 1000 non-null   float64
#  10  Blood_Pressure_mmHg               1000 non-null   int64
# ...

# %% [markdown]
# weight_kg

# %%
df['Weight_kg'].describe()
# Out:
# count    1000.000000
# mean       84.602400
# std        20.088121
# min        50.000000
# 25%        66.600000
# 50%        85.200000
# 75%       102.000000
# max       119.700000
# Name: Weight_kg, dtype: float64

# %%
train_df=df.copy()

# %%
train_df['Weight_kg'].isnull().sum()
# Out:
# np.int64(0)

# %%
train_df.sample(2)
# Out:
#      Age  Gender  Weight_kg  Height_cm   BMI  Disease_Type  Severity  \
# 604   70       0      117.3        180  36.2           NaN  Moderate
# 658   40       1       51.6        183  15.4  Hypertension    Severe
#
#     Physical_Activity_Level  Daily_Caloric_Intake  Cholesterol_mg/dL  \
# 604               Sedentary                  2968              199.3
# 658                Moderate                  2910              165.5
#
#      Blood_Pressure_mmHg  Glucose_mg/dL Dietary_Restrictions Allergies  \
# 604                  172          109.1                  NaN       NaN
# 658                  136          101.3            Low_Sugar       NaN
#
#     Preferred_Cuisine  Weekly_Exercise_Hours  Adherence_to_Diet_Plan  \
# 604           Chinese                    5.9                    66.6
# 658            Indian                    8.3                    50.2
#
#      Dietary_Nutrient_Imbalance_Score Diet_Recommendation
# 604                               1.9            Balanced
# ...

# %% [markdown]
# Height_cm

# %%
train_df['Height_cm'].describe()
# Out:
# count    1000.00000
# mean      174.81700
# std        14.33377
# min       150.00000
# 25%       162.00000
# 50%       175.00000
# 75%       187.00000
# max       199.00000
# Name: Height_cm, dtype: float64

# %% [markdown]
# BMI

# %%
train_df['BMI'].describe()
# Out:
# count    1000.000000
# mean       28.191600
# std         8.040136
# min        13.000000
# 25%        22.075000
# 50%        27.450000
# 75%        33.425000
# max        52.400000
# Name: BMI, dtype: float64

# %% [markdown]
# Disease_Type

# %%
train_df['Disease_Type'].value_counts()
# Out:
# Disease_Type
# Hypertension    316
# Diabetes        258
# Obesity         222
# Name: count, dtype: int64

# %%
train_df['Disease_Type'].isnull().sum()
# Out:
# np.int64(204)

# %%
train_df[train_df['Disease_Type'].isna()]
# Out:
#      Age  Gender  Weight_kg  Height_cm   BMI Disease_Type  Severity  \
# 3     32       1       58.1        164  21.6          NaN      Mild
# 6     78       1      102.2        170  35.4          NaN      Mild
# 14    41       1       83.7        154  35.3          NaN  Moderate
# 20    39       0      106.3        198  27.1          NaN    Severe
# 21    70       1       87.7        168  31.1          NaN  Moderate
# ..   ...     ...        ...        ...   ...          ...       ...
# 956   67       1       53.9        153  23.0          NaN      Mild
# 973   30       0       59.2        190  16.4          NaN      Mild
# 974   63       0       77.9        184  23.0          NaN  Moderate
# 976   78       0       83.0        197  21.4          NaN  Moderate
# 986   47       0       80.0        186  23.1          NaN      Mild
#
#     Physical_Activity_Level  Daily_Caloric_Intake  Cholesterol_mg/dL  \
# 3                  Moderate                  2657              168.2
# ...

# %% [markdown]
# replacing the nan value of the diesease into no diabetes as for now

# %%
train_df['Disease_Type']=train_df['Disease_Type'].fillna('Normal')

# %%
train_df['Disease_Type'].value_counts()
# Out:
# Disease_Type
# Hypertension    316
# Diabetes        258
# Obesity         222
# Normal          204
# Name: count, dtype: int64

# %%
train_df.sample(2)
# Out:
#      Age  Gender  Weight_kg  Height_cm   BMI Disease_Type  Severity  \
# 636   31       1       66.7        158  26.7       Normal  Moderate
# 893   79       1       58.7        160  22.9     Diabetes    Severe
#
#     Physical_Activity_Level  Daily_Caloric_Intake  Cholesterol_mg/dL  \
# 636                Moderate                  3347              213.7
# 893                Moderate                  2792              177.8
#
#      Blood_Pressure_mmHg  Glucose_mg/dL Dietary_Restrictions Allergies  \
# 636                  124          131.3            Low_Sugar    Gluten
# 893                  166          146.2                  NaN    Gluten
#
#     Preferred_Cuisine  Weekly_Exercise_Hours  Adherence_to_Diet_Plan  \
# 636           Italian                    6.1                    85.1
# 893           Italian                    3.2                    81.4
#
#      Dietary_Nutrient_Imbalance_Score Diet_Recommendation
# 636                               4.3            Balanced
# ...

# %% [markdown]
# # Severity
# define as the  stage he/she is curently on

# %%
train_df['Severity'].value_counts()
# Out:
# Severity
# Severe      344
# Moderate    342
# Mild        314
# Name: count, dtype: int64

# %%
train_df['Severity'].isnull().sum()
# Out:
# np.int64(0)

# %%
train_df['Severity']=train_df['Severity'].map({'Mild':0, 'Moderate':1, 'Severe':2}).astype(int)

# %%
train_df['Severity'].value_counts()
# Out:
# Severity
# 2    344
# 1    342
# 0    314
# Name: count, dtype: int64

# %%
train_df.sample(2)
# Out:
#      Age  Gender  Weight_kg  Height_cm   BMI Disease_Type  Severity  \
# 122   42       1       96.3        195  25.3      Obesity         1
# 80    64       0      106.1        170  36.7       Normal         2
#
#     Physical_Activity_Level  Daily_Caloric_Intake  Cholesterol_mg/dL  \
# 122                Moderate                  1959              154.9
# 80                   Active                  2015              232.6
#
#      Blood_Pressure_mmHg  Glucose_mg/dL Dietary_Restrictions Allergies  \
# 122                  169          129.3                  NaN    Gluten
# 80                   138          160.1                  NaN    Gluten
#
#     Preferred_Cuisine  Weekly_Exercise_Hours  Adherence_to_Diet_Plan  \
# 122           Mexican                    8.9                    50.5
# 80            Mexican                    5.2                    58.9
#
#      Dietary_Nutrient_Imbalance_Score Diet_Recommendation
# 122                               3.4            Balanced
# ...

# %% [markdown]
# Physical_Activity_Level

# %%
train_df['Physical_Activity_Level'].value_counts()
# Out:
# Physical_Activity_Level
# Moderate     335
# Active       335
# Sedentary    330
# Name: count, dtype: int64

# %%
train_df['Physical_Activity_Level'].isnull().sum()
# Out:
# np.int64(0)

# %%
train_df['Physical_Activity_Level']=train_df['Physical_Activity_Level'].map({'Sedentary':1.2, 'Moderate':1.55, 'Active':1.725}).astype('float')

# %%
train_df.sample(2)
# Out:
#      Age  Gender  Weight_kg  Height_cm   BMI  Disease_Type  Severity  \
# 55    54       0       53.2        151  23.3       Obesity         2
# 337   24       0      105.5        199  26.6  Hypertension         0
#
#      Physical_Activity_Level  Daily_Caloric_Intake  Cholesterol_mg/dL  \
# 55                     1.725                  2392              223.6
# 337                    1.200                  2744              213.0
#
#      Blood_Pressure_mmHg  Glucose_mg/dL Dietary_Restrictions Allergies  \
# 55                   176          178.5           Low_Sodium    Gluten
# 337                  170          189.8                  NaN       NaN
#
#     Preferred_Cuisine  Weekly_Exercise_Hours  Adherence_to_Diet_Plan  \
# 55            Mexican                    0.3                    52.3
# 337            Indian                    2.1                    89.4
#
#      Dietary_Nutrient_Imbalance_Score Diet_Recommendation
# ...

# %% [markdown]
# # Daily_Caloric_Intake

# %%
train_df['Daily_Caloric_Intake'].describe()
# Out:
# count    1000.000000
# mean     2475.064000
# std       565.017032
# min      1500.000000
# 25%      1984.750000
# 50%      2470.500000
# 75%      2937.250000
# max      3498.000000
# Name: Daily_Caloric_Intake, dtype: float64

# %%
train_df.sample(2)
# Out:
#      Age  Gender  Weight_kg  Height_cm   BMI  Disease_Type  Severity  \
# 308   34       1       80.4        179  25.1  Hypertension         2
# 53    74       0       69.4        171  23.7  Hypertension         2
#
#      Physical_Activity_Level  Daily_Caloric_Intake  Cholesterol_mg/dL  \
# 308                      1.2                  3343              166.7
# 53                       1.2                  3141              221.0
#
#      Blood_Pressure_mmHg  Glucose_mg/dL Dietary_Restrictions Allergies  \
# 308                  148           77.1           Low_Sodium   Peanuts
# 53                   174          142.5                  NaN       NaN
#
#     Preferred_Cuisine  Weekly_Exercise_Hours  Adherence_to_Diet_Plan  \
# 308           Mexican                    9.8                    82.4
# 53            Mexican                    2.5                    79.0
#
#      Dietary_Nutrient_Imbalance_Score Diet_Recommendation
# ...

# %%
train_df.sample(2)
# Out:
#      Age  Gender  Weight_kg  Height_cm   BMI  Disease_Type  Severity  \
# 559   32       0       64.4        152  27.9  Hypertension         0
# 506   43       0       86.6        159  34.3      Diabetes         0
#
#      Physical_Activity_Level  Daily_Caloric_Intake  Cholesterol_mg/dL  \
# 559                     1.55                  1864              183.3
# 506                     1.20                  3062              212.7
#
#      Blood_Pressure_mmHg  Glucose_mg/dL Dietary_Restrictions Allergies  \
# 559                  158           81.0            Low_Sugar       NaN
# 506                  175          131.5                  NaN       NaN
#
#     Preferred_Cuisine  Weekly_Exercise_Hours  Adherence_to_Diet_Plan  \
# 559           Chinese                    9.2                    96.8
# 506           Mexican                    2.1                    99.3
#
#      Dietary_Nutrient_Imbalance_Score Diet_Recommendation
# ...

# %%
df.drop(columns=['Adherence_to_Diet_Plan','BMI','Allergies','Preferred_Cuisine','Dietary_Restrictions','Dietary_Nutrient_Imbalance_Score'],inplace=True)

# %%
df.head()
# Out:
#    Age  Gender  Weight_kg  Height_cm  Disease_Type  Severity  \
# 0   56       1       58.4        160       Obesity  Moderate
# 1   69       1      101.2        169      Diabetes      Mild
# 2   46       0       63.5        173  Hypertension      Mild
# 3   32       1       58.1        164           NaN      Mild
# 4   60       1       79.5        197      Diabetes  Moderate
#
#   Physical_Activity_Level  Daily_Caloric_Intake  Cholesterol_mg/dL  \
# 0                Moderate                  3079              173.3
# 1                Moderate                  3032              199.2
# 2               Sedentary                  1737              181.0
# 3                Moderate                  2657              168.2
# 4               Sedentary                  3496              200.4
#
#    Blood_Pressure_mmHg  Glucose_mg/dL  Weekly_Exercise_Hours  \
# 0                  133          116.3                    3.1
# 1                  120          137.1                    4.5
# ...

# %%
df.isnull().sum()
# Out:
# Age                          0
# Gender                       0
# Weight_kg                    0
# Height_cm                    0
# Disease_Type               204
# Severity                     0
# Physical_Activity_Level      0
# Daily_Caloric_Intake         0
# Cholesterol_mg/dL            0
# Blood_Pressure_mmHg          0
# Glucose_mg/dL                0
# Weekly_Exercise_Hours        0
# Diet_Recommendation          0
# dtype: int64

# %%
df['Disease_Type']=df['Disease_Type'].fillna('Normal')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1000 non-null   int64
#  1   Gender                   1000 non-null   int64
#  2   Weight_kg                1000 non-null   float64
#  3   Height_cm                1000 non-null   int64
#  4   Disease_Type             1000 non-null   object
#  5   Severity                 1000 non-null   object
#  6   Physical_Activity_Level  1000 non-null   object
#  7   Daily_Caloric_Intake     1000 non-null   int64
#  8   Cholesterol_mg/dL        1000 non-null   float64
#  9   Blood_Pressure_mmHg      1000 non-null   int64
#  10  Glucose_mg/dL            1000 non-null   float64
#  11  Weekly_Exercise_Hours    1000 non-null   float64
#  12  Diet_Recommendation      1000 non-null   object
# dtypes: float64(4), int64(5), object(4)
# ...

# %%
df.to_csv("D:\\medical-11\\data\\processed_diet_recommendations_dataset.csv",index=False)
